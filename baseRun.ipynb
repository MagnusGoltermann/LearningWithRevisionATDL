# %%
# !pip install medmnist
# !pip install timm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 11.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/ATDL A3/LearningWithRevisionATDL/training_models"
# Out:
# /content/drive/MyDrive/ATDL A3/LearningWithRevisionATDL/training_models

# %%
# !python main.py --model mobilenet_v2 --mode train_with_revision --epoch 30 \
  --save_path cifar10_tests/abs_fixed_mobilenet_v2_tau090_run1 \
  --dataset cifar10 --batch_size 32 \
  --start_revision 29 --task classification \
  --threshold-method fixed --tau-min 0.90
# Out:
# 2025-10-30 17:52:38.960020: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-30 17:52:38.977844: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761846758.999734    5112 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761846759.006142    5112 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python main.py --model mobilenet_v2 --mode train_with_revision --epoch 30 \
  --save_path cifar10_tests/abs_fixed_mobilenet_v2_tau050_run1 \
  --dataset cifar10 --batch_size 32 \
  --start_revision 29 --task classification \
  --threshold-method fixed --tau-min 0.50
# Out:
# 2025-10-30 19:03:08.763772: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-30 19:03:08.781665: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761850988.803813   23296 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761850988.810522   23296 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python main.py --model mobilenet_v2 --mode train_with_revision --epoch 30 \
  --save_path cifar10_tests/abs_fixed_mobilenet_v2_tau030_run1 \
  --dataset cifar10 --batch_size 32 \
  --start_revision 29 --task classification \
  --threshold-method fixed --tau-min 0.30
# Out:
# 2025-10-30 20:12:23.529629: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-30 20:12:23.547810: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761855143.569861   41148 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761855143.576324   41148 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python main.py --model mobilenet_v2 --mode baseline --epoch 30 \
  --save_path cifar10_tests/baseline_mobilenet_v2_run1 \
  --dataset cifar10 --batch_size 32 --task classification

# %%
# DBPD - Linear (high→low)
# !python main.py --model mobilenet_v2 --mode train_with_revision --epoch 30 \
  --save_path cifar10_tests/linear_mobilenet_v2_run1 \
  --dataset cifar10 --batch_size 32 \
  --start_revision 29 --task classification \
  --threshold-method linear --tau-min 0.9 --tau-max 0.1
# Out:
# 2025-10-29 10:45:26.929587: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-29 10:45:26.947364: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761734726.969346    9721 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761734726.975967    9721 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# DBPD - Exponential (high→low)
# !python main.py --model mobilenet_v2 --mode train_with_revision --epoch 30 \
  --save_path cifar10_tests/exp_mobilenet_v2_k5_run1 \
  --dataset cifar10 --batch_size 32 \
  --start_revision 29 --task classification \
  --threshold-method exp --tau-min 0.9 --tau-max 0.1 --exp-k 5.0
# Out:
# 2025-10-29 16:07:32.386681: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-29 16:07:32.403932: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761754052.424782   50472 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761754052.431109   50472 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Three fixed relative margins (small→looser), saved separately

# Very strict: only very ambiguous correct samples included
# !python main.py --model mobilenet_v2 --mode train_with_revision --epoch 30 \
  --save_path cifar10_tests/relative_mobilenet_v2_margin005 \
  --dataset cifar10 --batch_size 32 \
  --start_revision 29 --task classification \
  --threshold-method relative --tau-min 0.05
# Out:
# 2025-10-29 12:47:42.209585: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-29 12:47:42.227149: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761742062.249191    1091 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761742062.255704    1091 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Moderate
# !python main.py --model mobilenet_v2 --mode train_with_revision --epoch 30 \
  --save_path cifar10_tests/relative_mobilenet_v2_margin010 \
  --dataset cifar10 --batch_size 32 \
  --start_revision 29 --task classification \
  --threshold-method relative --tau-min 0.10
# Out:
# 2025-10-29 13:54:49.046363: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-29 13:54:49.065613: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761746089.087978   18000 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761746089.094673   18000 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Looser: includes more correct samples
# !python main.py --model mobilenet_v2 --mode train_with_revision --epoch 30 \
  --save_path cifar10_tests/relative_mobilenet_v2_margin020 \
  --dataset cifar10 --batch_size 32 \
  --start_revision 29 --task classification \
  --threshold-method relative --tau-min 0.20
# Out:
# 2025-10-29 15:01:08.728974: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-29 15:01:08.746397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761750068.767641   34225 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761750068.774075   34225 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
